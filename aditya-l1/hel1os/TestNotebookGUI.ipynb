# %%
# !pip install plotly astropy pandas numpy ipywidgets
# Out:
# Requirement already satisfied: plotly in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (6.1.2)
# Requirement already satisfied: astropy in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (7.1.0)
# Requirement already satisfied: pandas in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (2.3.0)
# Requirement already satisfied: numpy in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: ipywidgets in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (8.1.7)
# Requirement already satisfied: narwhals>=1.15.1 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from plotly) (1.44.0)
# Requirement already satisfied: packaging in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from plotly) (25.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from astropy) (0.2025.6.23.0.39.50)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from astropy) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: comm>=0.1.3 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
# %pip install anywidget
# Out:
# Collecting anywidget
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from anywidget) (8.1.7)
# Collecting psygnal>=0.8.1 (from anywidget)
#   Downloading psygnal-0.15.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from anywidget) (4.14.0)
# Requirement already satisfied: comm>=0.1.3 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipywidgets>=7.6.0->anywidget) (3.0.15)
# Requirement already satisfied: decorator in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (2.19.2)
# Requirement already satisfied: stack_data in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.6.3)
# Requirement already satisfied: wcwidth in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (3.0.0)
# Requirement already satisfied: pure-eval in /home/manju/anaconda3/envs/sunpy_env/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget) (0.2.3)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Downloading psygnal-0.15.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (884 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.0/885.0 kB 650.6 kB/s eta 0:00:001m729.9 kB/s eta 0:00:01
# Installing collected packages: psygnal, anywidget
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [anywidget]━ 1/2 [anywidget]
# Successfully installed anywidget-0.9.21 psygnal-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run ./analysis_tools/TypeII-to-TypeI_V06_plotly.py CdTe_Combined_TypeII_spectra.fits CZT_Combined_TypeII_spectra.fits
# Out:
# Lightcurves displayed.
# You can now generate SCIENCE Type I PHA files by typing time ranges.
# Times must be in the same absolute system as the lightcurve (DATE_OBS / TIME_OBS).
# Example format:  2023-12-15 07:10:00
# Enter START time for SCIENCE spectrum (YYYY-mm-dd HH:MM:SS) or press ENTER to quit:  2025-10-15 14:00:00
# Enter END time   for SCIENCE spectrum (YYYY-mm-dd HH:MM:SS):  2025-10-15 14:15:00
# Generating SCIENCE Type I PHA files for interval:
#   2025-10-15 14:00:00  -->  2025-10-15 14:15:00
# Science Type I file generated: cdte_140000_141500.fits
# Science Type I file generated: czt_140000_141500.fits
# ------------------------------------------------------------
# Next action? [N]ew science spectrum, [B]ackground (detector specific), [Q]uit:  B
# Enter CdTe BACKGROUND START time (YYYY-mm-dd HH:MM:SS) or press ENTER to skip CdTe background:  2025-10-15 12:35:00
# Enter CdTe BACKGROUND END time   (YYYY-mm-dd HH:MM:SS):  2025-10-15 12:55:00
# Generating CdTe BACKGROUND for interval:
#   2025-10-15 12:35:00  -->  2025-10-15 12:55:00
# Background Type I file generated: cdte_back_123500_125500.fits
# Enter CZT BACKGROUND START time  (YYYY-mm-dd HH:MM:SS) or press ENTER to skip CZT background:  2025-10-15 12:35:00
# Enter CZT BACKGROUND END time    (YYYY-mm-dd HH:MM:SS):  2025-10-15 12:55:00
# Generating CZT BACKGROUND for interval:
#   2025-10-15 12:35:00  -->  2025-10-15 12:55:00
# Background Type I file generated: czt_back_123500_125500.fits
# Next action? [N]ew science spectrum, [B]ackground (detector specific), [Q]uit:  q
# Exiting.
