# %% [markdown]
# # Downloading required packages

# %%
# !pip install astropy
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
ls
# Out:
# analysis_tools/  Spectrals-tools-verifcation.ipynb
# data/            TestNotebookGUI.ipynb
# HEL1OS.md        timing-tools-verifcation.ipynb
# images/

# %%
ls ./analysis_tools
# Out:
# evt-to-TypeII_V02.py  LcFromEvtFile_V03.py  TypeII-to-TypeI_V03_notebook.py

# %%
# !python ./analysis_tools/evt-to-TypeII_V02.py ./data/evt.fits
# Out:
# Type II spectra created: CdTe1_TypeII_spectra.fits
# Type II spectra created: CdTe2_TypeII_spectra.fits
# Type II spectra created: CZT1_TypeII_spectra.fits
# Type II spectra created: CZT2_TypeII_spectra.fits
# Type II spectra created: CdTe_Combined_TypeII_spectra.fits
# Type II spectra created: CZT_Combined_TypeII_spectra.fits

# %%
# making sperate directory
mkdir spectoolstest
# Out:
#   Cell In[5], line 2
#     mkdir spectoolstest
#           ^
# SyntaxError: invalid syntax

# %%
# copying event file to our new directory
cp evt.fits spectoolstest/

# %%
cd HEL1OS_tools/
# Out:
# /home/kiran/sciserver/HEL1OS_tools

# %%
# Copying necessary tool to our new directory
cp evt-to-TypeII.py TypeII-to-TypeI.py ../spectoolstest/

# %%
cd ../spectoolstest/
# Out:
# /home/kiran/sciserver/spectoolstest

# %%
ls
# Out:
# evt.fits  evt-to-TypeII.py  TypeII-to-TypeI.py

# %% [markdown]
# # Generating Type II files from  event file

# %%
# !python evt-to-TypeII.py
# Out:
# PHA Type II file created: cdte1_TypeII_spectra.fits
# PHA Type II file created: cdte2_TypeII_spectra.fits
# PHA Type II file created: czt1_TypeII_spectra.fits
# PHA Type II file created: czt2_TypeII_spectra.fits
# PHA Type II file created: cdte_Combined_TypeII_spectra.fits
# PHA Type II file created: czt_Combined_TypeII_spectra.fits

# %% [markdown]
# # Generating Type I files from Type II files

# %%
# !python TypeII-to-TypeI.py
# Out:
# Figure(1200x800)

# %%
ls
# Out:
# cdte1_TypeII_spectra.fits          czt_Combined_TypeII_spectra.fits
# cdte2_TypeII_spectra.fits          evt.fits
# cdte_Combined_TypeII_spectra.fits  evt-to-TypeII.py
# czt1_TypeII_spectra.fits           TypeII-to-TypeI.py
# czt2_TypeII_spectra.fits

# %%
# %run TypeII-to-TypeI.py
